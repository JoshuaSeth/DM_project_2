# %%
from data.load import load_data
import os
import numpy as np
import pandas as pd

# %%
df = load_data(num_rows=1000, fts_operations=[('srch_id', 'all', 'diff')], same_value_operations=[('prop_id', 'all', 'avg')])
# Out:
# No cache for this specific request, start loading base df from disk.
# generating same id features
# ...
# 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# Feature engineering columns with operations
# saving result of specific arguments to cache
# 100%|██████████| 500/500 [00:10<00:00, 48.97it/s]

# %%
df.to_csv('what.csv')

# %%
df['prop_id']

# %%
df[['prop_id', 'same_val_prop_id_price_usd_avg', 'price_usd']]
# Out:
#      prop_id  same_val_prop_id_price_usd_avg  price_usd
# 0        893                          104.77     104.77
# 1      10404                          170.74     170.74
# 2      21315                          179.80     179.80
# 3      27348                          602.77     602.77
# 4      29604                          143.58     143.58
# ..       ...                             ...        ...
# 995    16549                          123.00     123.00
# 996    31638                          355.00     355.00
# 997    35509                          299.00     299.00
# 998    35871                          408.00     408.00
# 999    41413                          136.00     136.00
#
# [1000 rows x 3 columns]
